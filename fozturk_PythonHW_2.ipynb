# %% [raw]
# The cite of this homework is the following article:
# Effect of B or N doping on the dielectric and electrical properties of ZnO at room temperature
# Ali Can Güler et al
# Mater. Res. Express 6 (2019) 065017
# https://doi.org/10.1088/2053-1591/ab0b83

# %% [raw]
# In this homework, I will try to reproduce Figure 2 in the article. The data related to this figure is given as an Excel file "ZNO_data_fig2.xlsx".

# %% [raw]
# Many chemical and physical structures of materials are examined in order to determine their usage areas. One of them is the determination of the dielectric coefficient, which is related to its electrical properties. The insulation constant or dielectric constant is the measurement of a material's ability to store charge on it, i.e. how an electric field is affected by an insulating medium.

# %% [markdown]
# The properties of materials can be changed by adding new atoms known as doping. Figure 2 shows the variation of the electric coefficient with the frequency of the applied electric field as a result of doping the Zinc oxide (ZnO) substrate with different percentages of Boron (B) or nitrogen (N) nanoparticles.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel (r'ZNO_data_fig2.xlsx', names=['Freq','ZNO_Eps','ZNO_N4_Eps','ZNO_B4_Eps','ZNO_N2_Eps','ZNO_B2_Eps'])

# %%
df.head()
# Out:
#          Freq  ZNO_Eps  ZNO_N4_Eps  ZNO_B4_Eps  ZNO_N2_Eps  ZNO_B2_Eps
# 0  10000000.0     2.47        2.55        1.89        2.29        2.26
# 1   7140000.0     2.47        2.57        1.90        2.30        2.27
# 2   5100000.0     2.47        2.57        1.90        2.30        2.27
# 3   3640000.0     2.47        2.58        1.90        2.30        2.27
# 4   2600000.0     2.47        2.58        1.89        2.30        2.27

# %%
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams['axes.linewidth'] = 2 
plt.figure(figsize=(12, 10))
plt.plot(df.Freq, df.ZNO_Eps, "-k", marker="s",label="ZNO")
plt.plot(df.Freq, df.ZNO_B2_Eps, "-r", marker="o", label="ZNO_B2")
plt.plot(df.Freq, df.ZNO_B4_Eps, "-b", marker=">", label="ZNO_B4")
plt.plot(df.Freq, df.ZNO_N2_Eps, "-g", marker="^", label="ZNO_N2")
plt.plot(df.Freq, df.ZNO_N4_Eps, "Magenta", marker="D", label="ZNO_N4")
plt.yscale("log")
plt.xscale("log")
plt.xlabel("f (Hz)", fontsize=22)
plt.ylabel('$\\epsilon^\prime$', fontsize=22)
plt.xticks(fontsize=22)
plt.yticks(fontsize=22)
plt.axis([10**-2, 10**7, 10**0, 3*10**3])
plt.legend(loc="center right",fontsize=20)
plt.savefig('ZNO_freq_vs_eps.pdf')
